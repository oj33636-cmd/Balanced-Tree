# %% [markdown]
# **1.**
#
# > (안 풀어도 된다고 하셨던 15, 18, 19번은 생략했습니다.)

# %% [markdown]
# **01** Θ(n), Θ(1)

# %% [markdown]
# **02** 삭제한 후이다. 삽입이었으면 그 전 과정애서도 AVL 트리 균형에 맞지 않았을 것이다.

# %% [markdown]
# **03** 둘 다 가능하다.

# %% [markdown]
# **04** ![IMG_7226.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **05** LR, RL

# %% [markdown]
# **06** 맞는 주장이 아니다. 높이가 유지될 수도 있다.

# %% [markdown]
# **07** 발생할 수 있다.

# %% [markdown]
# **08**  ![IMG_7227.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **09** 최악의 경우 루트까지 Red로 바뀌게 될 수 있다. (연속으로 Red인 노드들
# P,P1-> P1, P2-> P2, P3-> P3, P4-> P4, P5-> P5, P6)

# %% [markdown]
# **10**![IMG_7229.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **11**![IMG_7230.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **12**![IMG_7231.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **13**![IMG_7232.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **14** 원소의 직후 원소는 오른쪽 서브 트리에서 가장 작은 값이다. 즉, 왼쪽으로 계속해서 내려다가 더 이상 자식이 없어야 한다.

# %% [markdown]
# **15**

# %% [markdown]
# **16** k/2~k개라는 키 개수 범위를 가진다.

# %% [markdown]
# **17** 없다. 병합되는 두 노드가 최소 개수 근처의 키만 가지고 있기에 부모 키까지 합치더라도 넘지 않는다.

# %% [markdown]
# **18**

# %% [markdown]
# **19**
